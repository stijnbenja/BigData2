# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn import ensemble
from sklearn import linear_model
import seaborn as sns
import matplotlib.pyplot as plt
from functions import *
import warnings
import random
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
baskets, coupons, prediction_index = get_3_files()

# %%
n_customers = 20
customers = range(2000)#random.sample(range(2000),n_customers)
baskets = baskets[baskets['customer'].isin(customers)]
coupons = coupons[coupons['customer'].isin(customers)]
base = create_base(weeks=range(91),customers=customers)

# %%
base = add_basket_info(base, baskets)

# %%
base = add_categories(base)

# %%
base = add_frequencies(base, baskets) #Will generate frequencies based on available basket info

# %%
base = add_rolling_frequencies(base)

# %%
base = add_weeks_ago(base)

# %%
base = base.drop(['price','basket'],axis=1)

# %%
base
# Out:
#         week  customer  product  isBought  category  p_prod     p_cat  \
# 0          0      1218        0     False         0     0.0  0.211111
# 1          0      1218        1     False         0     0.0  0.211111
# 2          0      1218        2     False         0     0.0  0.211111
# 3          0      1218        3     False         0     0.0  0.211111
# 4          0      1218        4     False         0     0.0  0.211111
# ...      ...       ...      ...       ...       ...     ...       ...
# 454995    90       998      245     False        24     0.0  0.633333
# 454996    90       998      246     False        24     0.0  0.633333
# 454997    90       998      247     False        24     0.0  0.633333
# 454998    90       998      248     False        24     0.0  0.633333
# 454999    90       998      249     False        24     0.6  0.633333
#
#         roll_prod_5  roll_prod_10  roll_prod_30  weeks_ago
# 0               0.0           0.0           0.0       90.0
# ...

# %%
train = base[base['week']<90]
predict = base[base['week']==90]

# %%
x_train = train.drop('isBought',axis=1)
y_train = train['isBought']

# %%
x_predict = predict.drop('isBought',axis=1)

# %%
x_predict
# Out:
#         week  customer  product  category  p_prod     p_cat  roll_prod_5  \
# 450000    90      1218        0         0     0.0  0.211111          0.0
# 450001    90      1218        1         0     0.0  0.211111          0.0
# 450002    90      1218        2         0     0.0  0.211111          0.0
# 450003    90      1218        3         0     0.0  0.211111          0.0
# 450004    90      1218        4         0     0.0  0.211111          0.0
# ...      ...       ...      ...       ...     ...       ...          ...
# 454995    90       998      245        24     0.0  0.633333          0.0
# 454996    90       998      246        24     0.0  0.633333          0.0
# 454997    90       998      247        24     0.0  0.633333          0.0
# 454998    90       998      248        24     0.0  0.633333          0.0
# 454999    90       998      249        24     0.6  0.633333          0.0
#
#         roll_prod_10  roll_prod_30  weeks_ago
# ...

# %%
models = [
    ensemble.RandomForestClassifier(), #2.6%
    ensemble.GradientBoostingClassifier(), #1.9%
    ensemble.HistGradientBoostingClassifier() #2.4%
]

# %%
model_list = []

for model in models:
    print(model)
    model.fit(X = x_train, y = y_train)
    model_list.append(model)
# Out:
# RandomForestClassifier()
# GradientBoostingClassifier()
# HistGradientBoostingClassifier()

# %%
np.matrix(predictions_list).mean(axis=0)
# Out:
# matrix([[0.99999908, 0.99999908, 0.99999908, ..., 0.99999908, 0.99999908,
#          0.99999908]])

# %%
predictions = model.predict_proba(x_predict)[:,0]
predictions_list.append(predictions)

# %%
prediction_index['predictions'] =
# Out:
#         week customer product
# 0         90        0       0
# 1         90        0       1
# 2         90        0       2
# 3         90        0       3
# 4         90        0       4
# ...      ...      ...     ...
# 499995    90     1999     245
# 499996    90     1999     246
# 499997    90     1999     247
# 499998    90     1999     248
# 499999    90     1999     249
#
# [500000 rows x 3 columns]
